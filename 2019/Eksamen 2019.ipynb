# %% [markdown]
# > Opgave 1:
#
# **Lad x(t) være input og y(t) være output. Angiv hvilket af systemerne der er et LTIC system:** $\\$
# ![image.png](attachment:image.png)

# %% [markdown]
# A: **Ikke lineært**. pga. $y^2(𝑡)$. Ikke LTIC.
#
# B: **Ikke lineært**, fordi input $x(t)$ er i anden potens (x^2). Ikke LTIC
#
# C: Dette er en lineær differentialligning med konstant koefficient og input er $x(t)$. Lineært, tidsinvariant og kan antages kausalt.
#
# D: **Ikke lineært**, fordi højresiden indeholder en konstant. LTIC-systemer må ikke have uafhængige konstanter, da det bryder homogenitet.

# %% [markdown]
# > Opgave 2
#
# **Bestem integralet** $\\$
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > Opgave 3:
#
# **Et LTIC system har impulsreponset:** $\\$
# ![image.png](attachment:image.png)
#
# Angiv systemets respons på inputtet: $x(t)=u(t)$
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
#
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$
# ![image-7.png](attachment:image-7.png) $\\$
# ![image-8.png](attachment:image-8.png) $\\$

# %% [markdown]
# > Opgave 4:
#
# **Et LTIC system har impulsresponse:** $\\$
# ![image.png](attachment:image.png) $\\$
# Angiv systemets overføringsfunktion i laplacedomænet.

# %% [markdown]
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# > Opgave 5:
#
# **Et 1. ordens system er beskrevet ved ligningen:** $\\$
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
#
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 6:
#
# **Hvad er overføringsfunktionen i fourierdomænet systemet i Opgave 5?**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# > Opgave 7
#
# **Betragt et 2. ordens system med overføringsfunktion:** $\\$
# ![image.png](attachment:image.png) $\\$
# Hvilket af nedenst˚aende udsagn er korrekt
#
# ![image-2.png](attachment:image-2.png)
#
# C: **Ja, den er korekt** $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png)
#
# B: **Denne er forkert** $\\$
# ![image-5.png](attachment:image-5.png)
#
# A: **Denne er forkert** $\\$
# ![image-6.png](attachment:image-6.png)
#
# D: **Denne er forkert** $\\$
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 8:
#
# **Overføringsfunktionen H(s) for et LTIC system er:** $\\$
# ![image.png](attachment:image.png) $\\$
# Hvad er systemets respons på en enhedstrinpåvirkningen x(t) = u(t)?
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# > Opgave 9:
#
# **Funktionerne f(t) og g(t) har graferne:** $\\$
# ![image.png](attachment:image.png) $\\$
# Hvilken af graferne nedenfor fremstiller foldningsintegralet f ∗ g:

# %% [markdown]
# > Opgave 10:
#
# **Et LTIC-system er beskrevet ved ligningen:**
# $$\dot{y}(t) + y(t) = x(t)$$
# **Hvor x(t) betegner input og y(t) er output. Hvilket af nedenstående udsagn er $\textbf{ikke}$ korrekt.**
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# A: **Denne er korekt** $\\$
# ![image.png](attachment:image.png)
#
# B: **Denne er korekt** $\\$
# ![image-4.png](attachment:image-4.png)
#
# C: **** $\\$
# # Denne var der ikke et konkret svar på
#
# D: **Nej, den er ikke korekt** $\\$
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# > Opgave 11:
#
# **Lad F(s) betegne den unilateralt laplacetransformerede af:**
# $$f(t) = 1, \quad t \in \mathbb{R}$$
# **Hvilket af nedenstående udsagn er korrekt?**
#
# ![image-2.png](attachment:image-2.png) $\\$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > Opgave 12:
#
# **Hvis en funktion f(t) er antisymmetrisk, dvs. $f(t) = −f(−t)$, og samtidig er imaginær, dvs. $f(t) = −f(t)∗$. Hvad opfylder den fouriertransformerede F(ω) da?
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > Opgave 13:
#
# **Et 2. ordens system har overføringsfunktionen**
# $$H(s) = \frac{s^2}{s^2 + 4s + 4}$$
# **Hvilket af nedenst˚aende udsagn er korrek:**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# A: Systemet har poler i $p=\pm 2j \\$
# **Forkert, det ville betyde svingende respons uden dæmpning. Men her har vi reelle poler i −2.**
#
# B: Systemet er et lavpasfilter $\\$
# **Forkert, tælleren er $s^2$, hvilket giver nul gain ved lav frekvens. Det opfører sig som et højpasfilter.**
#
# C: Systemet er ustabilt: $\\$
# **Forkert, da polerne er i venstre halvplan.**
#
# D: Systemet er kritisk dæmpet: $\\$
# **Korrekt, fordi vi har to reelle og identiske poler.**

# %% [markdown]
# > Opgave 14:
#
# Et filter har diagrammet: $\\$
# ![image.png](attachment:image.png) $\\$
# hvor spændingen x(t) er input og spændingen y(t) er output. Hvilket af nedenstående er $\textbf{ikke}$ korrekt?
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-2.png](attachment:image-2.png)
#
# A: **Dette er korekt** $\\$
# ![image-3.png](attachment:image-3.png)
#
# B: **Dette er korekt** $\\$
# ![image-4.png](attachment:image-4.png)
#
# C: **Nej, Dette er ikke korekt** $\\$
# ![image-5.png](attachment:image-5.png)
#
# D: **Dette er korekt** $\\$
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# > Opgave 15:
# # Ikke fulført
#
# Betragt et Sallen-Key-filter: $\\$
# ![image.png](attachment:image.png)
# med forstærkning 1. Hvilket af nedenst˚aende udsagn er $\textbf{ikke}$ korrekt?
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# A: **Dette er korekt** $\\$
# Som beskrevet ovenfor, er dette korrekt – det er en højpasstruktur.
#
# B: **Dette er korekt** $\\$
# ![image-4.png](attachment:image-4.png)
#
# C:
#
# D: **Dette er korekt** $\\$
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# > Opgave 16:
#
# **Et normaliseret lavpasfilter har overføringsfunktionen** $\\$
# ![image.png](attachment:image.png) $\\$
# hvor 0<ζ≤1. Hvilken af nedenstående substitutioner skal foretages for at opnå et højpasfilter med knækfrekvens i $ω_n$?
#
# **A er korekt**
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png)
#
# # Denne er ikke korekt

# %% [markdown]
# > Opgave 17:
#
# **Et filter har i laplacedomænet overføringsfunktionen:**
# $$H(s) = \frac{s}{(s + 1)(s + 2)}$$
# **Hvad der værdien af impulsresponset umiddelbart efter 0.**
#
# ![image.png](attachment:image.png)
#
# **C er korekt**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > Opgave 18:
#
# **Et 2. ordens system har Bode-plottet:** $\\$
# ![image.png](attachment:image.png) $\\$
# **hvor “sort” svarer til det fulde system og de øvrige (stiplede) kurver svarer til faktoriseringen af systemet. Angiv hvilken overføringsfunktion der svarer til det viste Bode-plot**
#
# ![image-2.png](attachment:image-2.png) $\\$
#
# **A er den korekte** $\\$
# ![image-4.png](attachment:image-4.png) $\\$
#
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$

# %% [markdown]
# > Opgave 19:
#
# **Et LTIC system er beskrevet ved ligningen:**
# $$(D^2 + 2D + 5)y(t) = 5x(t) \\$$
# $$y(0−) = 0, \dot{y}(0−) = 0, x(t) = u(t)$$
# **Hvilket af nedenst˚aende er $\textbf{ikke}$ korrekt?**
#
# ![image.png](attachment:image.png)
#
# A: **Dette er korekt** $\\$
# ![image-2.png](attachment:image-2.png)
#
# B: **Dette er korekt** $\\$
# ![image-3.png](attachment:image-3.png)
#
# C: **Dette er korekt** $\\$
# # Denne mangler
#
# D: **Nej, Dette er ikke korekt** $\\$
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# > Opgave 20:
#
# Et tracking-filter har i laplacedomænet overføringsfunktionen $\\$
# ![image.png](attachment:image.png) $\\$
# Hvad kræves om konstanterne a og b, hvis den asymptotiske fejl på enhedsstepfunktionen (f(t) = u(t)) og et enhedsrampeinput (f(t) = r(t) = tu(t)) begge skal være 0. $\\$
#
# ![image-2.png](attachment:image-2.png)
#
# **A: Er korekt** $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png)
