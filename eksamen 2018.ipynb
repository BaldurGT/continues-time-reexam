# %% [markdown]
# > Opgave 1:
#
# **Lad x(t) være input og y(t) være output. Angiv hvilket af systemerne der er lineært.**
#
# ![image.png](attachment:image.png)
#
# **Rikgtig svar C**

# %% [markdown]
# > Opgave 2:
#
# **Et LTIC system har impulsreponset**
# $$h(t) = δ(t) − 2e^{-2t}u(t)$$
# **Angiv systemets respons på inputtet**
# $$x(t) = u(t)$$
# ![image-8.png](attachment:image-8.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 3:
#
# **Et LTIC system har impulsreponset:**
# $$h(t) = δ(t) − 2e^{−2t}u(t) $$
# **Angiv systemets overføringsfunktion i laplacedomænet** $\\$
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# > Opgave 4:
#
# **Et 1. ordens system er beskrevet ved ligningen:**
# $$\dot{y}(t) + 2y(t) = 2x(t)$$
# $y(0^−) = 3 \\$
# **Hvad er impulsresponset for systemet** $\\$
# ![image-4.png](attachment:image-4.png)
#
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# > Opgave 5:
#
# **Hvad er zero-input responset for systemet i Opgave 4?** $\\$
# ![image-7.png](attachment:image-7.png)
#
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
#
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# > Opgave 6:
#
# **Et LTIC-system er beskrevet ved ligningen**
# $$\ddot{y}(t) = 5x(t) $$
# **hvor x(t) betegner input og y(t) er output. Hvilket af nedenstående udsagn er korrekt** $\\$
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# A: **Denne er ikk sandt** $\\$
# ![image-3.png](attachment:image-3.png)
#
# B: **** $\\$
# ![image-5.png](attachment:image-5.png)
#
# C: **Denne er sandt** $\\$
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# > Opgave 7:
#
# **Dekomposition af systemet beskrevet ved afbildningen**
# $$x(t) → y(t)$$
# $D^iy(0^−) = α_i, \space i = 0, ...,(n − 1) \\$
# **betyder, at outputtet y(t) kan opdeles som en sum**
# $$y(t) = y_{zs}(t) + y_{zi}(t)$$
# **hvor begyndelsesbetingelserne lige før påvirkningen x(t) starter er $\\$**
# $D^iy_{zi}(0^−) = α_i, \qquad i = 0, ...,(n − 1) \\ $
# $D^iy_{zs}(0−) = 0, \qquad i = 0, ...,(n − 1) \\ $
# **og $y_{zi}$ ikke afhænger af den kausale påvirkning x.$\\$**
# **Angiv tilstrækkelige betingelser for at dekompositionsprincippet gælder for afbildningen.** $\\$
# ![image-2.png](attachment:image-2.png) $\\$
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png)
#
# **C er korekt**

# %% [markdown]
# > Opgave 8
#
# **Hvis en funktion f(t) er reel, dvs. $f(t)=f(t)*$, hvad opfylder den fouriertransformerede F(ω) da:**
# ![image-3.png](attachment:image-3.png) $\\$
#
# **A er den korekte**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > Opgave 9:
#
# **Bestem den fouriertransformerede af**
# $$f(t) = δ(t − t0)$$
# **Angiv den korrekte værdi**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# > Opgave 10:
#
# ![image.png](attachment:image.png)
#
# A: **Denne er korekt** $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png)
#
# B: **Denne er korekt** $\\$
# ![image-5.png](attachment:image-5.png)
#
# C: **Denne er korekt** $\\$
# ![image-6.png](attachment:image-6.png)
#
# D: **Nej, denne er ikke sandt** $\\$
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 11
#
# **Et 1. ordens system er beskrevet ved ligningen**
# $$\dot{y}(t) + y(t) = 2x(t), \qquad y(0^−) = 4$$
# **Hvad er impulsresponset for systemet**
#
# ![image.png](attachment:image.png)
#
# **C er riktig** $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$

# %% [markdown]
# > Opgave 12:
#
# **Hvad er zero-input responset for systemet i opgave 11.** $\\$
# ![image.png](attachment:image.png)
#
# **C er den korekte**
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png)
#
# $$y(t) = 4e^{-t}u(t)$$

# %% [markdown]
# > Opgave 13:
#
# **Et LTIC-system er beskrevet ved ligningen**
# $$(D + 1)y(t) = 2x(t), \qquad y(0−) = 4$$
# **Hvad er systemets samlede respons på inputtet:**
# $x(t) = 2u(t)?$
#
# ![image-5.png](attachment:image-5.png)
#
# **D er den som er korekt**
#
# ![image.png](attachment:image.png) $\\$
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$

# %% [markdown]
# > Opgave 14:
#
# **Et 1. ordens system giver ved inputtet x(t) = u(t) outputtet vist i figuren** $\\$
# ![image.png](attachment:image.png) $\\$
# **Hvad er systemets overføringsfunktion i laplacedomænet?**
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$
#
# ![image-6.png](attachment:image-6.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 15:
#
# **Det oplyses at overføringsfunktionen H(s) for et system er**
# $$H(s) = \frac{s + 1}{s − 1}$$
# **Hvilket af nedenstående udsagn er korrekt?** $\\$
# ![image-2.png](attachment:image-2.png)
#
# **C, er korekt** $\\$
# ![image.png](attachment:image.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$

# %% [markdown]
# > Opgave 16:
#
# **Et filter har i laplacedomænet overføringsfunktionen**
# $$H(s) = \frac{s^2}{(s + 1)(s + 2)}$$
# **Hvad der værdien af impulsresponset umiddelbart efter 0.** $\\$
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png) $\\$
# ![image-3.png](attachment:image-3.png) $\\$
# ![image-4.png](attachment:image-4.png) $\\$

# %% [markdown]
# > Opgave 17
#
# **Et 2. ordens system har Bode-plottet:** $\\$
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png) $\\$
# **Hvor “sort” svarer til det fulde system og de øvrige (stiplede) kurver svarer til faktoriseringen af systemet. Angiv hvilken overføringsfunktion der svarer til det viste Bode-plot.** $\\$
# ![image-8.png](attachment:image-8.png)
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# **B, er korekt** $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$
# ![image-7.png](attachment:image-7.png) $\\$
# ![image-9.png](attachment:image-9.png) $\\$
# ![image-10.png](attachment:image-10.png) $\\$
#
# Aflese bode-plot $\\$
# ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png) $\\$
# ![image-13.png](attachment:image-13.png)

# %% [markdown]
# > Opgave 18:
#
# **Figuren viser pol-nulpunktsdiagrammet for et LTIC system:** $\\$
# ![image.png](attachment:image.png) $\\$
# **Med forstærkning 1. Røde kryds angiver poler og der er ingen nulpunkter. Hvilket af nedenstående er korrekt?** $\\$
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
#
# A: **Denne er ikke korekt** $\\$
# ![image-5.png](attachment:image-5.png)
#
# B: **Denne er ikke korekt** $\\$
# ![image-6.png](attachment:image-6.png)
#
# C: **Denne er korekt** $\\$
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# > Opgave 19
#
# **Et LTIC system er beskrevet ved ligningen:**
# $$(D^2 + 2D + 5)y(t) = D^2x(t)$$
# $y(0^−) = 0, \quad \dot{y}(0^−) = 0, \quad x(t) = 5u(t) \\$
# **Hvilket af nedenstående er ikke korrekt?** $\\$
# ![image.png](attachment:image.png)
#
# A **Denne er korekt** $\\$
# ![image-2.png](attachment:image-2.png)
#
# B: **Denne er korekt** $\\$
# ![image-3.png](attachment:image-3.png)
#
# C: **Denne er korekt** $\\$
# ![image-4.png](attachment:image-4.png)
#
# D: **Nej, denne er ikke korekt** $\\$
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# > Opgave 20
#
# **Betragt kredsløbe:** $\\$
# ![image.png](attachment:image.png)
#
# hvor L=1H, R=2Ω, $C=\frac{1}{5}F$ og i(t) angiver strømmen i kredsløbet. Efter at have været forbundet i lang tid afbrydes kontakten til tiden t=0. Hvilket af nedenstående udsagn er ikke korrekt? $\\$
# ![image-2.png](attachment:image-2.png)
#
# B: **Denne er korekt** $\\$
# ![image-3.png](attachment:image-3.png)
#
# A: **Denne er korekt** $\\$
# ![image-4.png](attachment:image-4.png) $\\$
# ![image-5.png](attachment:image-5.png) $\\$
# ![image-6.png](attachment:image-6.png) $\\$
# ![image-7.png](attachment:image-7.png) $\\$
# ![image-8.png](attachment:image-8.png) $\\$
#
# C: **Denne er korekt** $\\$
# ![image-9.png](attachment:image-9.png)
#
# D: **Nej, Denne er ikke korekt** $\\$
# ![image-10.png](attachment:image-10.png)
